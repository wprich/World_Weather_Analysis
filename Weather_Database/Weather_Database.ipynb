# %%
# Import the dependencies.
import pandas as pd
import gmaps
from datetime import datetime
import requests
from citipy import citipy
import random
import time
import numpy as np
import timeit
from scipy.stats import linregress
import matplotlib.pyplot as plt
# Import the API key.
from config import g_key
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Create a variable to hold the lat. and long. pairs
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 778

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        # If an error is experienced, skip the city.
        city_weather = requests.get(city_url).json()
        #print(city_weather)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Current Description": city_description})
                            #"Date": city_date})
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | coihaique
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | adrar
# Processing Record 6 of Set 1 | cambyreta
# City not found. Skipping...
# Processing Record 7 of Set 1 | esperance
# Processing Record 8 of Set 1 | zyryanka
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | granville
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | northam
# Processing Record 13 of Set 1 | east london
# Processing Record 14 of Set 1 | flinders
# Processing Record 15 of Set 1 | cherskiy
# Processing Record 16 of Set 1 | klaksvik
# Processing Record 17 of Set 1 | vestmanna
# Processing Record 18 of Set 1 | nanzhang
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | urrao
# Processing Record 21 of Set 1 | vila velha
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | clyde river
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | coquimbo
# Processing Record 28 of Set 1 | dehloran
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | vao
# Processing Record 32 of Set 1 | santa fe
# Processing Record 33 of Set 1 | avera
# Processing Record 34 of Set 1 | kruisfontein
# Processing Record 35 of Set 1 | san patricio
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | saint-remi
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | la asuncion
# Processing Record 40 of Set 1 | ambilobe
# Processing Record 41 of Set 1 | fomboni
# Processing Record 42 of Set 1 | urumqi
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | fortuna
# Processing Record 45 of Set 1 | tiarei
# Processing Record 46 of Set 1 | port hardy
# Processing Record 47 of Set 1 | berlevag
# Processing Record 48 of Set 1 | saint-paul
# Processing Record 49 of Set 1 | lahij
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | saint-pierre
# Processing Record 2 of Set 2 | kargasok
# Processing Record 3 of Set 2 | pevek
# Processing Record 4 of Set 2 | cairns
# Processing Record 5 of Set 2 | carnarvon
# Processing Record 6 of Set 2 | grindavik
# Processing Record 7 of Set 2 | cortez
# Processing Record 8 of Set 2 | san cristobal
# Processing Record 9 of Set 2 | jalu
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | sinfra
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | emirdag
# Processing Record 14 of Set 2 | matara
# Processing Record 15 of Set 2 | waipawa
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 2 | iqaluit
# Processing Record 19 of Set 2 | vardo
# Processing Record 20 of Set 2 | comodoro rivadavia
# Processing Record 21 of Set 2 | tasiilaq
# Processing Record 22 of Set 2 | tiksi
# Processing Record 23 of Set 2 | saskylakh
# Processing Record 24 of Set 2 | mar del plata
# Processing Record 25 of Set 2 | oranjemund
# Processing Record 26 of Set 2 | khatanga
# Processing Record 27 of Set 2 | paamiut
# Processing Record 28 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 2 | dunda
# Processing Record 30 of Set 2 | weligama
# Processing Record 31 of Set 2 | luderitz
# Processing Record 32 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 2 | tuatapere
# Processing Record 34 of Set 2 | severo-kurilsk
# Processing Record 35 of Set 2 | sobolevo
# Processing Record 36 of Set 2 | georgetown
# Processing Record 37 of Set 2 | castro
# Processing Record 38 of Set 2 | kholtoson
# Processing Record 39 of Set 2 | ilo
# Processing Record 40 of Set 2 | balkanabat
# Processing Record 41 of Set 2 | dikson
# Processing Record 42 of Set 2 | tuktoyaktuk
# Processing Record 43 of Set 2 | hasaki
# Processing Record 44 of Set 2 | sedelnikovo
# City not found. Skipping...
# Processing Record 45 of Set 2 | west wendover
# Processing Record 46 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 2 | arraial do cabo
# Processing Record 48 of Set 2 | sheopur
# Processing Record 49 of Set 2 | salyan
# Processing Record 50 of Set 2 | dubbo
# Processing Record 1 of Set 3 | kodinar
# Processing Record 2 of Set 3 | vila
# Processing Record 3 of Set 3 | bima
# Processing Record 4 of Set 3 | san jeronimo
# Processing Record 5 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 3 | lavrentiya
# Processing Record 7 of Set 3 | ponta do sol
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | husavik
# Processing Record 10 of Set 3 | victoria
# Processing Record 11 of Set 3 | hithadhoo
# Processing Record 12 of Set 3 | el salto
# Processing Record 13 of Set 3 | gizo
# Processing Record 14 of Set 3 | albina
# Processing Record 15 of Set 3 | lukulu
# Processing Record 16 of Set 3 | podgornaya
# Processing Record 17 of Set 3 | ahipara
# Processing Record 18 of Set 3 | tambun
# Processing Record 19 of Set 3 | nikolskoye
# Processing Record 20 of Set 3 | cascais
# Processing Record 21 of Set 3 | rafai
# Processing Record 22 of Set 3 | raudeberg
# Processing Record 23 of Set 3 | hachinohe
# Processing Record 24 of Set 3 | marienburg
# Processing Record 25 of Set 3 | asau
# Processing Record 26 of Set 3 | puerto ayora
# Processing Record 27 of Set 3 | kayes
# Processing Record 28 of Set 3 | bengkulu
# Processing Record 29 of Set 3 | ostersund
# Processing Record 30 of Set 3 | kununurra
# Processing Record 31 of Set 3 | winnemucca
# Processing Record 32 of Set 3 | hobart
# Processing Record 33 of Set 3 | cayenne
# Processing Record 34 of Set 3 | kasongo-lunda
# Processing Record 35 of Set 3 | capim grosso
# Processing Record 36 of Set 3 | surt
# Processing Record 37 of Set 3 | taoudenni
# Processing Record 38 of Set 3 | kahului
# Processing Record 39 of Set 3 | saint george
# Processing Record 40 of Set 3 | khandyga
# Processing Record 41 of Set 3 | kedougou
# Processing Record 42 of Set 3 | new norfolk
# Processing Record 43 of Set 3 | pinsk
# Processing Record 44 of Set 3 | aptos
# Processing Record 45 of Set 3 | broome
# Processing Record 46 of Set 3 | torbay
# Processing Record 47 of Set 3 | borlange
# City not found. Skipping...
# Processing Record 48 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 3 | hanzhong
# Processing Record 50 of Set 3 | zhigansk
# Processing Record 1 of Set 4 | sao paulo de olivenca
# Processing Record 2 of Set 4 | narsaq
# Processing Record 3 of Set 4 | buala
# Processing Record 4 of Set 4 | karakendzha
# City not found. Skipping...
# Processing Record 5 of Set 4 | chuy
# Processing Record 6 of Set 4 | itarema
# Processing Record 7 of Set 4 | lebu
# Processing Record 8 of Set 4 | geraldton
# Processing Record 9 of Set 4 | tual
# Processing Record 10 of Set 4 | faanui
# Processing Record 11 of Set 4 | butaritari
# Processing Record 12 of Set 4 | tautira
# Processing Record 13 of Set 4 | kodiak
# Processing Record 14 of Set 4 | bluff
# Processing Record 15 of Set 4 | puerto quijarro
# Processing Record 16 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 4 | leningradskiy
# Processing Record 18 of Set 4 | suez
# Processing Record 19 of Set 4 | tigil
# Processing Record 20 of Set 4 | margate
# Processing Record 21 of Set 4 | madimba
# Processing Record 22 of Set 4 | abu samrah
# Processing Record 23 of Set 4 | hopkinsville
# Processing Record 24 of Set 4 | eirunepe
# Processing Record 25 of Set 4 | ewa beach
# Processing Record 26 of Set 4 | ardino
# Processing Record 27 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 28 of Set 4 | corowa
# Processing Record 29 of Set 4 | qaanaaq
# Processing Record 30 of Set 4 | dunayivtsi
# City not found. Skipping...
# Processing Record 31 of Set 4 | saint-philippe
# Processing Record 32 of Set 4 | port elizabeth
# Processing Record 33 of Set 4 | deputatskiy
# Processing Record 34 of Set 4 | san francisco del mar
# Processing Record 35 of Set 4 | pangnirtung
# Processing Record 36 of Set 4 | souillac
# Processing Record 37 of Set 4 | yeppoon
# Processing Record 38 of Set 4 | pitimbu
# Processing Record 39 of Set 4 | bonthe
# Processing Record 40 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 4 | takoradi
# Processing Record 42 of Set 4 | eureka
# Processing Record 43 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 44 of Set 4 | constantine
# Processing Record 45 of Set 4 | bandarbeyla
# Processing Record 46 of Set 4 | cap malheureux
# Processing Record 47 of Set 4 | calvinia
# Processing Record 48 of Set 4 | san vicente
# Processing Record 49 of Set 4 | chokurdakh
# Processing Record 50 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 5 | praia
# Processing Record 2 of Set 5 | kieta
# Processing Record 3 of Set 5 | ippy
# Processing Record 4 of Set 5 | rocha
# Processing Record 5 of Set 5 | antofagasta
# Processing Record 6 of Set 5 | dingle
# Processing Record 7 of Set 5 | abha
# Processing Record 8 of Set 5 | eyrarbakki
# Processing Record 9 of Set 5 | dunedin
# Processing Record 10 of Set 5 | nuzvid
# Processing Record 11 of Set 5 | sao felix do xingu
# Processing Record 12 of Set 5 | cidreira
# Processing Record 13 of Set 5 | katobu
# Processing Record 14 of Set 5 | thompson
# Processing Record 15 of Set 5 | plettenberg bay
# Processing Record 16 of Set 5 | vestmannaeyjar
# Processing Record 17 of Set 5 | constitucion
# Processing Record 18 of Set 5 | ilulissat
# Processing Record 19 of Set 5 | coahuayana
# Processing Record 20 of Set 5 | champoton
# Processing Record 21 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 22 of Set 5 | lazaro cardenas
# Processing Record 23 of Set 5 | kabelvag
# Processing Record 24 of Set 5 | macroom
# Processing Record 25 of Set 5 | lubango
# Processing Record 26 of Set 5 | isangel
# Processing Record 27 of Set 5 | cao bang
# Processing Record 28 of Set 5 | batticaloa
# Processing Record 29 of Set 5 | baykit
# Processing Record 30 of Set 5 | camacha
# Processing Record 31 of Set 5 | umm durman
# City not found. Skipping...
# Processing Record 32 of Set 5 | qaqortoq
# Processing Record 33 of Set 5 | saldanha
# Processing Record 34 of Set 5 | sur
# Processing Record 35 of Set 5 | beringovskiy
# Processing Record 36 of Set 5 | alta
# Processing Record 37 of Set 5 | lompoc
# Processing Record 38 of Set 5 | san ignacio
# Processing Record 39 of Set 5 | sebeta
# Processing Record 40 of Set 5 | abasha
# Processing Record 41 of Set 5 | sao joao da barra
# Processing Record 42 of Set 5 | nouadhibou
# Processing Record 43 of Set 5 | taonan
# Processing Record 44 of Set 5 | strezhevoy
# Processing Record 45 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 5 | dongsheng
# Processing Record 48 of Set 5 | zaachila
# City not found. Skipping...
# Processing Record 49 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 5 | mitsamiouli
# Processing Record 1 of Set 6 | labuan
# Processing Record 2 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 6 | quelimane
# Processing Record 4 of Set 6 | mildura
# Processing Record 5 of Set 6 | saint-francois
# Processing Record 6 of Set 6 | navahrudak
# Processing Record 7 of Set 6 | bhinmal
# Processing Record 8 of Set 6 | gravdal
# Processing Record 9 of Set 6 | bonavista
# Processing Record 10 of Set 6 | goundam
# Processing Record 11 of Set 6 | aksu
# Processing Record 12 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 6 | belaya gora
# Processing Record 14 of Set 6 | nome
# Processing Record 15 of Set 6 | santa rosa
# Processing Record 16 of Set 6 | airai
# Processing Record 17 of Set 6 | iskateley
# Processing Record 18 of Set 6 | korla
# Processing Record 19 of Set 6 | palafrugell
# Processing Record 20 of Set 6 | aklavik
# Processing Record 21 of Set 6 | canon city
# Processing Record 22 of Set 6 | pisco
# Processing Record 23 of Set 6 | shizunai
# Processing Record 24 of Set 6 | thinadhoo
# Processing Record 25 of Set 6 | mehamn
# Processing Record 26 of Set 6 | simpang
# Processing Record 27 of Set 6 | kutum
# Processing Record 28 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 6 | gushikawa
# Processing Record 30 of Set 6 | misratah
# Processing Record 31 of Set 6 | trinidad
# Processing Record 32 of Set 6 | wanaka
# Processing Record 33 of Set 6 | moose jaw
# Processing Record 34 of Set 6 | sitka
# Processing Record 35 of Set 6 | hamilton
# Processing Record 36 of Set 6 | suluq
# Processing Record 37 of Set 6 | batemans bay
# Processing Record 38 of Set 6 | namibe
# Processing Record 39 of Set 6 | dingli
# Processing Record 40 of Set 6 | pingxiang
# Processing Record 41 of Set 6 | laguna
# Processing Record 42 of Set 6 | ystad
# Processing Record 43 of Set 6 | dolores
# Processing Record 44 of Set 6 | provideniya
# Processing Record 45 of Set 6 | kulhudhuffushi
# Processing Record 46 of Set 6 | kesinga
# Processing Record 47 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 6 | saint-joseph
# Processing Record 49 of Set 6 | marzuq
# Processing Record 50 of Set 6 | aykhal
# Processing Record 1 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 7 | fairbanks
# Processing Record 3 of Set 7 | ambanja
# Processing Record 4 of Set 7 | te anau
# Processing Record 5 of Set 7 | cabo san lucas
# Processing Record 6 of Set 7 | etchojoa
# Processing Record 7 of Set 7 | sibut
# Processing Record 8 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 7 | natal
# Processing Record 10 of Set 7 | palmer
# Processing Record 11 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 7 | bambanglipuro
# Processing Record 13 of Set 7 | kloulklubed
# Processing Record 14 of Set 7 | guerrero negro
# Processing Record 15 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 16 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 17 of Set 7 | olean
# Processing Record 18 of Set 7 | hambantota
# Processing Record 19 of Set 7 | talnakh
# Processing Record 20 of Set 7 | gat
# Processing Record 21 of Set 7 | spring valley
# Processing Record 22 of Set 7 | olavarria
# Processing Record 23 of Set 7 | myitkyina
# Processing Record 24 of Set 7 | pinega
# Processing Record 25 of Set 7 | dingzhou
# Processing Record 26 of Set 7 | akonolinga
# Processing Record 27 of Set 7 | pochutla
# Processing Record 28 of Set 7 | russell
# Processing Record 29 of Set 7 | maceio
# Processing Record 30 of Set 7 | angoram
# Processing Record 31 of Set 7 | panzhihua
# Processing Record 32 of Set 7 | lebowakgomo
# Processing Record 33 of Set 7 | copala
# Processing Record 34 of Set 7 | port-gentil
# Processing Record 35 of Set 7 | zaragoza
# Processing Record 36 of Set 7 | north bend
# Processing Record 37 of Set 7 | lola
# Processing Record 38 of Set 7 | san isidro
# Processing Record 39 of Set 7 | ribeira grande
# Processing Record 40 of Set 7 | mandalgovi
# Processing Record 41 of Set 7 | cody
# Processing Record 42 of Set 7 | mayo
# Processing Record 43 of Set 7 | olafsvik
# Processing Record 44 of Set 7 | poya
# Processing Record 45 of Set 7 | mungaoli
# Processing Record 46 of Set 7 | ponca city
# Processing Record 47 of Set 7 | aswan
# Processing Record 48 of Set 7 | ikalamavony
# Processing Record 49 of Set 7 | yanaul
# Processing Record 50 of Set 7 | springfield
# Processing Record 1 of Set 8 | ancud
# Processing Record 2 of Set 8 | westport
# Processing Record 3 of Set 8 | los llanos de aridane
# Processing Record 4 of Set 8 | altamira
# Processing Record 5 of Set 8 | hay river
# Processing Record 6 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 7 of Set 8 | lorengau
# Processing Record 8 of Set 8 | sao filipe
# Processing Record 9 of Set 8 | verkhoturye
# Processing Record 10 of Set 8 | antsla
# Processing Record 11 of Set 8 | bahia honda
# Processing Record 12 of Set 8 | san quintin
# Processing Record 13 of Set 8 | shimoda
# Processing Record 14 of Set 8 | lugovskiy
# City not found. Skipping...
# Processing Record 15 of Set 8 | portland
# Processing Record 16 of Set 8 | yuzhnyy
# Processing Record 17 of Set 8 | de-kastri
# Processing Record 18 of Set 8 | annau
# Processing Record 19 of Set 8 | kirovohrad
# Processing Record 20 of Set 8 | tarnogskiy gorodok
# Processing Record 21 of Set 8 | hailar
# Processing Record 22 of Set 8 | mount gambier
# Processing Record 23 of Set 8 | zaysan
# Processing Record 24 of Set 8 | high level
# Processing Record 25 of Set 8 | guamuchil
# Processing Record 26 of Set 8 | kinablangan
# Processing Record 27 of Set 8 | visimo-utkinsk
# City not found. Skipping...
# Processing Record 28 of Set 8 | roald
# Processing Record 29 of Set 8 | burica
# City not found. Skipping...
# Processing Record 30 of Set 8 | cosala
# Processing Record 31 of Set 8 | mackay
# Processing Record 32 of Set 8 | taltal
# Processing Record 33 of Set 8 | regina
# Processing Record 34 of Set 8 | omboue
# Processing Record 35 of Set 8 | scarborough
# Processing Record 36 of Set 8 | bambous virieux
# Processing Record 37 of Set 8 | zheleznogorsk
# Processing Record 38 of Set 8 | kaeo
# Processing Record 39 of Set 8 | elizabeth city
# Processing Record 40 of Set 8 | bangassou
# Processing Record 41 of Set 8 | nenjiang
# Processing Record 42 of Set 8 | nioro
# Processing Record 43 of Set 8 | mahebourg
# Processing Record 44 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 8 | nishihara
# Processing Record 46 of Set 8 | mantua
# Processing Record 47 of Set 8 | bandar
# Processing Record 48 of Set 8 | sistranda
# Processing Record 49 of Set 8 | savannah bight
# Processing Record 50 of Set 8 | kavaratti
# Processing Record 1 of Set 9 | yumen
# Processing Record 2 of Set 9 | asyut
# Processing Record 3 of Set 9 | nara
# Processing Record 4 of Set 9 | havelock
# Processing Record 5 of Set 9 | forquilhinha
# Processing Record 6 of Set 9 | kilindoni
# Processing Record 7 of Set 9 | dwarka
# Processing Record 8 of Set 9 | phu ly
# Processing Record 9 of Set 9 | cilegon
# Processing Record 10 of Set 9 | bathsheba
# Processing Record 11 of Set 9 | saint-augustin
# Processing Record 12 of Set 9 | keti bandar
# Processing Record 13 of Set 9 | ormara
# Processing Record 14 of Set 9 | bergerac
# Processing Record 15 of Set 9 | cortes
# Processing Record 16 of Set 9 | samarai
# Processing Record 17 of Set 9 | santona
# Processing Record 18 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 19 of Set 9 | vostok
# Processing Record 20 of Set 9 | quatre cocos
# Processing Record 21 of Set 9 | jiblah
# Processing Record 22 of Set 9 | vilhena
# Processing Record 23 of Set 9 | macusani
# Processing Record 24 of Set 9 | znamenskoye
# Processing Record 25 of Set 9 | port lincoln
# Processing Record 26 of Set 9 | cockburn town
# Processing Record 27 of Set 9 | meulaboh
# Processing Record 28 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 29 of Set 9 | inhambane
# Processing Record 30 of Set 9 | boras
# Processing Record 31 of Set 9 | srednekolymsk
# Processing Record 32 of Set 9 | estelle
# Processing Record 33 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 9 | lasa
# Processing Record 35 of Set 9 | soyo
# Processing Record 36 of Set 9 | katsuura
# Processing Record 37 of Set 9 | kimbe
# Processing Record 38 of Set 9 | tilichiki
# Processing Record 39 of Set 9 | henties bay
# Processing Record 40 of Set 9 | upernavik
# Processing Record 41 of Set 9 | nizhniy ufaley
# Processing Record 42 of Set 9 | praxedis guerrero
# Processing Record 43 of Set 9 | teya
# Processing Record 44 of Set 9 | mikuni
# Processing Record 45 of Set 9 | warri
# Processing Record 46 of Set 9 | yulara
# Processing Record 47 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 9 | manavalakurichi
# Processing Record 49 of Set 9 | porbandar
# Processing Record 50 of Set 9 | herzogenbuchsee
# Processing Record 1 of Set 10 | bereda
# Processing Record 2 of Set 10 | mahanoro
# Processing Record 3 of Set 10 | tura
# Processing Record 4 of Set 10 | port blair
# Processing Record 5 of Set 10 | port hedland
# Processing Record 6 of Set 10 | anantapur
# Processing Record 7 of Set 10 | bukoba
# Processing Record 8 of Set 10 | jawhar
# Processing Record 9 of Set 10 | kaitangata
# Processing Record 10 of Set 10 | kjollefjord
# Processing Record 11 of Set 10 | tumen
# Processing Record 12 of Set 10 | puerto baquerizo moreno
# Processing Record 13 of Set 10 | redlands
# Processing Record 14 of Set 10 | ambon
# Processing Record 15 of Set 10 | marsh harbour
# Processing Record 16 of Set 10 | barra
# Processing Record 17 of Set 10 | ponferrada
# Processing Record 18 of Set 10 | codrington
# Processing Record 19 of Set 10 | zapolyarnyy
# Processing Record 20 of Set 10 | ruteng
# Processing Record 21 of Set 10 | rio gallegos
# Processing Record 22 of Set 10 | williams lake
# Processing Record 23 of Set 10 | faya
# Processing Record 24 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 25 of Set 10 | san diego de los banos
# Processing Record 26 of Set 10 | beihai
# Processing Record 27 of Set 10 | prabumulih
# Processing Record 28 of Set 10 | mahajanga
# Processing Record 29 of Set 10 | cururupu
# Processing Record 30 of Set 10 | huilong
# Processing Record 31 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 10 | ejido
# Processing Record 33 of Set 10 | nabire
# Processing Record 34 of Set 10 | maragogi
# Processing Record 35 of Set 10 | norman wells
# Processing Record 36 of Set 10 | chinsali
# Processing Record 37 of Set 10 | ucluelet
# Processing Record 38 of Set 10 | olenino
# Processing Record 39 of Set 10 | jurado
# Processing Record 40 of Set 10 | requena
# Processing Record 41 of Set 10 | teknaf
# Processing Record 42 of Set 10 | okmulgee
# Processing Record 43 of Set 10 | atbasar
# Processing Record 44 of Set 10 | umm lajj
# Processing Record 45 of Set 10 | shizukuishi
# Processing Record 46 of Set 10 | coolum beach
# Processing Record 47 of Set 10 | eyl
# Processing Record 48 of Set 10 | abu dhabi
# Processing Record 49 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 10 | mahabad
# Processing Record 1 of Set 11 | rawson
# Processing Record 2 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 11 | kalangala
# Processing Record 4 of Set 11 | saint-georges
# Processing Record 5 of Set 11 | preobrazheniye
# Processing Record 6 of Set 11 | boddam
# Processing Record 7 of Set 11 | kirando
# Processing Record 8 of Set 11 | sal rei
# Processing Record 9 of Set 11 | lucapa
# Processing Record 10 of Set 11 | beroroha
# Processing Record 11 of Set 11 | lincoln
# Processing Record 12 of Set 11 | cuencame
# Processing Record 13 of Set 11 | otane
# Processing Record 14 of Set 11 | aloleng
# Processing Record 15 of Set 11 | lufilufi
# Processing Record 16 of Set 11 | siverek
# Processing Record 17 of Set 11 | piopio
# Processing Record 18 of Set 11 | kavieng
# Processing Record 19 of Set 11 | molepolole
# Processing Record 20 of Set 11 | shingu
# Processing Record 21 of Set 11 | altay
# Processing Record 22 of Set 11 | abong mbang
# Processing Record 23 of Set 11 | ugoofaaru
# Processing Record 24 of Set 11 | clyde
# Processing Record 25 of Set 11 | barcelos
# Processing Record 26 of Set 11 | tevriz
# Processing Record 27 of Set 11 | youkounkoun
# Processing Record 28 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 29 of Set 11 | kazachinskoye
# Processing Record 30 of Set 11 | san policarpo
# Processing Record 31 of Set 11 | alpine
# Processing Record 32 of Set 11 | kwinana
# Processing Record 33 of Set 11 | general pico
# Processing Record 34 of Set 11 | nanortalik
# Processing Record 35 of Set 11 | troitsko-pechorsk
# Processing Record 36 of Set 11 | ketchikan
# Processing Record 37 of Set 11 | cabedelo
# Processing Record 38 of Set 11 | kandrian
# Processing Record 39 of Set 11 | verkhnevilyuysk
# Processing Record 40 of Set 11 | kisangani
# Processing Record 41 of Set 11 | howard springs
# Processing Record 42 of Set 11 | thano bula khan
# City not found. Skipping...
# Processing Record 43 of Set 11 | bojnurd
# Processing Record 44 of Set 11 | elat
# Processing Record 45 of Set 11 | presidencia roque saenz pena
# Processing Record 46 of Set 11 | lethem
# Processing Record 47 of Set 11 | dessau
# Processing Record 48 of Set 11 | pringsewu
# Processing Record 49 of Set 11 | tsukumi
# Processing Record 50 of Set 11 | chara
# Processing Record 1 of Set 12 | mnogovershinnyy
# Processing Record 2 of Set 12 | ouallam
# Processing Record 3 of Set 12 | concepcion del oro
# Processing Record 4 of Set 12 | karratha
# Processing Record 5 of Set 12 | mercedes
# Processing Record 6 of Set 12 | mount isa
# Processing Record 7 of Set 12 | tobol
# Processing Record 8 of Set 12 | tacuarembo
# Processing Record 9 of Set 12 | araouane
# Processing Record 10 of Set 12 | ayorou
# Processing Record 11 of Set 12 | nemuro
# Processing Record 12 of Set 12 | arman
# Processing Record 13 of Set 12 | batagay-alyta
# Processing Record 14 of Set 12 | thai binh
# Processing Record 15 of Set 12 | san rafael
# Processing Record 16 of Set 12 | vung tau
# Processing Record 17 of Set 12 | akureyri
# Processing Record 18 of Set 12 | sabha
# Processing Record 19 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 20 of Set 12 | korem
# Processing Record 21 of Set 12 | opuwo
# Processing Record 22 of Set 12 | rock sound
# Processing Record 23 of Set 12 | biak
# Processing Record 24 of Set 12 | lovozero
# Processing Record 25 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 26 of Set 12 | sagua la grande
# Processing Record 27 of Set 12 | nagua
# Processing Record 28 of Set 12 | richards bay
# Processing Record 29 of Set 12 | dole
# Processing Record 30 of Set 12 | kirakira
# Processing Record 31 of Set 12 | birjand
# Processing Record 32 of Set 12 | alofi
# Processing Record 33 of Set 12 | kungurtug
# Processing Record 34 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 12 | nassjo
# Processing Record 36 of Set 12 | college
# Processing Record 37 of Set 12 | rivne
# Processing Record 38 of Set 12 | carutapera
# Processing Record 39 of Set 12 | high rock
# Processing Record 40 of Set 12 | saint-denis
# Processing Record 41 of Set 12 | khristoforovo
# City not found. Skipping...
# Processing Record 42 of Set 12 | mogadishu
# Processing Record 43 of Set 12 | bayan
# Processing Record 44 of Set 12 | catamarca
# Processing Record 45 of Set 12 | fojnica
# Processing Record 46 of Set 12 | nueva loja
# Processing Record 47 of Set 12 | campoverde
# Processing Record 48 of Set 12 | mizdah
# Processing Record 49 of Set 12 | makakilo city
# Processing Record 50 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 13 | awbari
# Processing Record 2 of Set 13 | port antonio
# Processing Record 3 of Set 13 | kawardha
# Processing Record 4 of Set 13 | sisimiut
# Processing Record 5 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 6 of Set 13 | doha
# Processing Record 7 of Set 13 | ballsh
# Processing Record 8 of Set 13 | brenham
# Processing Record 9 of Set 13 | koumac
# Processing Record 10 of Set 13 | vanimo
# Processing Record 11 of Set 13 | venado tuerto
# Processing Record 12 of Set 13 | filingue
# Processing Record 13 of Set 13 | abonnema
# Processing Record 14 of Set 13 | am timan
# Processing Record 15 of Set 13 | port moresby
# Processing Record 16 of Set 13 | pilar
# Processing Record 17 of Set 13 | jinchang
# Processing Record 18 of Set 13 | mattru
# Processing Record 19 of Set 13 | sioux lookout
# Processing Record 20 of Set 13 | healdsburg
# Processing Record 21 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 13 | nyaregyhaza
# Processing Record 23 of Set 13 | nador
# Processing Record 24 of Set 13 | panaba
# Processing Record 25 of Set 13 | hirara
# Processing Record 26 of Set 13 | karatsu
# Processing Record 27 of Set 13 | khani
# Processing Record 28 of Set 13 | naze
# Processing Record 29 of Set 13 | andevoranto
# City not found. Skipping...
# Processing Record 30 of Set 13 | onverwacht
# Processing Record 31 of Set 13 | goderich
# Processing Record 32 of Set 13 | fez
# Processing Record 33 of Set 13 | visby
# Processing Record 34 of Set 13 | pleasant point
# Processing Record 35 of Set 13 | tawnat
# City not found. Skipping...
# Processing Record 36 of Set 13 | khor
# Processing Record 37 of Set 13 | terme
# Processing Record 38 of Set 13 | wakkanai
# Processing Record 39 of Set 13 | gwadar
# Processing Record 40 of Set 13 | bowen
# Processing Record 41 of Set 13 | wajima
# Processing Record 42 of Set 13 | tefe
# Processing Record 43 of Set 13 | farmos
# Processing Record 44 of Set 13 | kerrville
# Processing Record 45 of Set 13 | kismayo
# Processing Record 46 of Set 13 | hami
# Processing Record 47 of Set 13 | svetlogorsk
# Processing Record 48 of Set 13 | luba
# Processing Record 49 of Set 13 | mpika
# Processing Record 50 of Set 13 | la cumbre
# Processing Record 1 of Set 14 | oum hadjer
# Processing Record 2 of Set 14 | batagay
# Processing Record 3 of Set 14 | kitimat
# Processing Record 4 of Set 14 | honiara
# Processing Record 5 of Set 14 | montepuez
# Processing Record 6 of Set 14 | bella union
# Processing Record 7 of Set 14 | khujner
# Processing Record 8 of Set 14 | caravelas
# Processing Record 9 of Set 14 | mangan
# Processing Record 10 of Set 14 | shcholkine
# City not found. Skipping...
# Processing Record 11 of Set 14 | lebyazhye
# Processing Record 12 of Set 14 | xuddur
# Processing Record 13 of Set 14 | champerico
# Processing Record 14 of Set 14 | buena vista
# Processing Record 15 of Set 14 | naryan-mar
# Processing Record 16 of Set 14 | isiro
# Processing Record 17 of Set 14 | galiakot
# Processing Record 18 of Set 14 | keffi
# Processing Record 19 of Set 14 | palaikastron
# Processing Record 20 of Set 14 | chanika
# Processing Record 21 of Set 14 | cicero dantas
# Processing Record 22 of Set 14 | bac lieu
# Processing Record 23 of Set 14 | oktyabrskiy
# Processing Record 24 of Set 14 | usinsk
# Processing Record 25 of Set 14 | codajas
# Processing Record 26 of Set 14 | bolec
# Processing Record 27 of Set 14 | praya
# Processing Record 28 of Set 14 | mantsala
# Processing Record 29 of Set 14 | shache
# Processing Record 30 of Set 14 | mrakovo
# Processing Record 31 of Set 14 | fare
# Processing Record 32 of Set 14 | alekseyevsk
# Processing Record 33 of Set 14 | aitape
# Processing Record 34 of Set 14 | ladario
# Processing Record 35 of Set 14 | cabra
# Processing Record 36 of Set 14 | callaway
# Processing Record 37 of Set 14 | jiayuguan
# Processing Record 38 of Set 14 | latung
# Processing Record 39 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 40 of Set 14 | ponta pora
# Processing Record 41 of Set 14 | rundu
# Processing Record 42 of Set 14 | san mateo del mar
# Processing Record 43 of Set 14 | villa carlos paz
# Processing Record 44 of Set 14 | ji-parana
# City not found. Skipping...
# Processing Record 45 of Set 14 | kysyl-syr
# Processing Record 46 of Set 14 | zholymbet
# Processing Record 47 of Set 14 | waddan
# Processing Record 48 of Set 14 | sakhnovshchyna
# Processing Record 49 of Set 14 | salamiyah
# Processing Record 50 of Set 14 | price
# Processing Record 1 of Set 15 | hearst
# Processing Record 2 of Set 15 | ascension
# Processing Record 3 of Set 15 | pozo colorado
# Processing Record 4 of Set 15 | bilma
# Processing Record 5 of Set 15 | ojinaga
# Processing Record 6 of Set 15 | karpathos
# Processing Record 7 of Set 15 | tobermory
# Processing Record 8 of Set 15 | camapua
# Processing Record 9 of Set 15 | verkhnyaya inta
# Processing Record 10 of Set 15 | mana
# Processing Record 11 of Set 15 | hofn
# Processing Record 12 of Set 15 | xiaoweizhai
# Processing Record 13 of Set 15 | manaure
# Processing Record 14 of Set 15 | hokitika
# Processing Record 15 of Set 15 | myanaung
# Processing Record 16 of Set 15 | sept-iles
# Processing Record 17 of Set 15 | tombouctou
# Processing Record 18 of Set 15 | fasa
# Processing Record 19 of Set 15 | gizycko
# Processing Record 20 of Set 15 | bloomsburg
# Processing Record 21 of Set 15 | cobija
# Processing Record 22 of Set 15 | saiha
# Processing Record 23 of Set 15 | sibenik
# Processing Record 24 of Set 15 | valparaiso
# Processing Record 25 of Set 15 | batsfjord
# Processing Record 26 of Set 15 | talara
# Processing Record 27 of Set 15 | okha
# Processing Record 28 of Set 15 | lagoa
# Processing Record 29 of Set 15 | sarishabari
# Processing Record 30 of Set 15 | the valley
# Processing Record 31 of Set 15 | vikindu
# Processing Record 32 of Set 15 | poum
# Processing Record 33 of Set 15 | ampanihy
# Processing Record 34 of Set 15 | ust-kuyga
# Processing Record 35 of Set 15 | chernyshevskiy
# Processing Record 36 of Set 15 | brandfort
# Processing Record 37 of Set 15 | ban nahin
# Processing Record 38 of Set 15 | sinnamary
# Processing Record 39 of Set 15 | kyabe
# Processing Record 40 of Set 15 | hualmay
# Processing Record 41 of Set 15 | elbistan
# Processing Record 42 of Set 15 | izhma
# Processing Record 43 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 15 | acarau
# Processing Record 45 of Set 15 | kemi
# Processing Record 46 of Set 15 | jiaocheng
# Processing Record 47 of Set 15 | sudak
# Processing Record 48 of Set 15 | boca do acre
# Processing Record 49 of Set 15 | maun
# Processing Record 50 of Set 15 | tezu
# Processing Record 1 of Set 16 | telimele
# Processing Record 2 of Set 16 | baruun-urt
# Processing Record 3 of Set 16 | nizhneangarsk
# Processing Record 4 of Set 16 | jamkhed
# Processing Record 5 of Set 16 | mago
# Processing Record 6 of Set 16 | roros
# Processing Record 7 of Set 16 | kamaishi
# Processing Record 8 of Set 16 | torit
# Processing Record 9 of Set 16 | quang ngai
# Processing Record 10 of Set 16 | sambava
# Processing Record 11 of Set 16 | channel-port aux basques
# Processing Record 12 of Set 16 | ahuimanu
# Processing Record 13 of Set 16 | krasnoarmeysk
# Processing Record 14 of Set 16 | verkhoyansk
# Processing Record 15 of Set 16 | ola
# Processing Record 16 of Set 16 | mushie
# Processing Record 17 of Set 16 | kushmurun
# Processing Record 18 of Set 16 | shelburne
# Processing Record 19 of Set 16 | villacarrillo
# Processing Record 20 of Set 16 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 16 | harper
# Processing Record 22 of Set 16 | hope
# Processing Record 23 of Set 16 | zhangye
# Processing Record 24 of Set 16 | kyren
# Processing Record 25 of Set 16 | teguise
# Processing Record 26 of Set 16 | raga
# Processing Record 27 of Set 16 | loiza
# Processing Record 28 of Set 16 | chimbote
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
weather_database_df = pd.DataFrame(city_data)
weather_database_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Ushuaia -54.8000  -68.3000     29.86        86          75       17.27
# 1  Coihaique -45.5752  -72.0662     43.41        75          75        4.61
# 2       Hilo  19.7297 -155.0900     73.13        90          90        5.75
# 3     Bethel  41.3712  -73.4140     84.38        71           1       10.36
# 4      Adrar  20.5022  -10.0711    104.49        18           3       13.60
# 5  Esperance -33.8667  121.9000     58.84        83         100       18.39
# 6   Zyryanka  65.7500  150.8500     46.04        90          23        8.14
# 7  Busselton -33.6500  115.3333     59.09        92         100       14.94
# 8  Granville -33.8333  151.0167     54.30        71          75        1.01
# 9      Vaini -21.2000 -175.2000     66.36        82          20        6.91
#
#   Country Current Description
# 0      AR          light snow
# 1      CL          light rain
# 2      US          light rain
# 3      US           clear sky
# 4      MR           clear sky
# 5      AU          light rain
# 6      RU          few clouds
# 7      AU          light rain
# 8      AU       broken clouds
# 9      TO          few clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
weather_database_df = weather_database_df[new_column_order]
weather_database_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Ushuaia      AR -54.8000  -68.3000     29.86        86          75
# 1  Coihaique      CL -45.5752  -72.0662     43.41        75          75
# 2       Hilo      US  19.7297 -155.0900     73.13        90          90
# 3     Bethel      US  41.3712  -73.4140     84.38        71           1
# 4      Adrar      MR  20.5022  -10.0711    104.49        18           3
# 5  Esperance      AU -33.8667  121.9000     58.84        83         100
# 6   Zyryanka      RU  65.7500  150.8500     46.04        90          23
# 7  Busselton      AU -33.6500  115.3333     59.09        92         100
# 8  Granville      AU -33.8333  151.0167     54.30        71          75
# 9      Vaini      TO -21.2000 -175.2000     66.36        82          20
#
#    Wind Speed Current Description
# 0       17.27          light snow
# 1        4.61          light rain
# 2        5.75          light rain
# 3       10.36           clear sky
# 4       13.60           clear sky
# 5       18.39          light rain
# 6        8.14          few clouds
# 7       14.94          light rain
# 8        1.01       broken clouds
# 9        6.91          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weatherpy_Database.csv"
# Export the City_Data into a CSV.
weather_database_df.to_csv(output_data_file, index_label="City_ID")
